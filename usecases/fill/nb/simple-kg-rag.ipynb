# %% [markdown]
# # A simple chatbot agent

# %% [markdown]
# ## Prepare the environment

# %%
import sys
sys.path.append('../../..')

from autogen import ConversableAgent, register_function

# from inswitch.llm.model import get_openai_model_config
from inswitch.agent.basic import get_chat_agent, get_fixed_reply_agent
from inswitch.util import second_last_msg

from rdflib import Graph, URIRef

# %% [markdown]
# ## The functions to query the complete kg
# TODO: generalize it to work on given ttl files.

# %%
kg = Graph()
kg.parse("../data/anonimized_data_fill.ttl")

def query_kg(query:str)->str:
    skg = kg.query(query)

    result = ""
    for s, p, o in skg:
        # Use namespace_manager to abbreviate URIs
        subject_prefix = kg.namespace_manager.qname(s)
        predicate_prefix = kg.namespace_manager.qname(p)
        object_prefix = kg.namespace_manager.qname(o) if isinstance(o, URIRef) else f'"{o}"'
        
        # Print in the desired format
        result = result + f"{subject_prefix} {predicate_prefix} {object_prefix}\n"
    return result

def get_sample_kg()->str:
    return query_kg("""
        SELECT (SAMPLE(?subject) AS ?sampleSubject) ?predicate  (SAMPLE(?object) AS ?sampleObject)
        WHERE {
        # ?subject ?predicate ?object .
        }
        GROUP BY ?predicate
    """)

def get_namespaces()->str:

    return """
@prefix fill: <https://intendproject.eu/fill/>.
@prefix intend: <https://intendproject.eu/schema/>.
@prefix schema: <https://schema.org/>.
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
    """

    # TODO: This does not work... Need to fix
    # return "\n".join(
    #     f"{prefix}: {namespace}" 
    #     for prefix, namespace in kg.namespace_manager.namespaces()
    #     if prefix in kg.namespace_manager.store.prefixes()
    # )


# print(get_sample_kg())
# print(get_namespaces())

# %% [markdown]
# ## Here are the API invocation agents

# %%
rdf_tool_driver_system_message = '''
You are a helpful assistant. From a user intent (provided in the context), you will
try to get all the knowledges that may be relevant to this intent.
You have access to a Knowledge Graph, and you can generate and execute sparql queries
to obtain a subgraph from the knowledge graph, and that subgraph is all the knowledge
that might be relevant to the intent.
You may do it step by step, starting from listing all the service descriptions, 
and see which exact service the intent is about. From the intent, you
can also know which active machine the user owns. Then, you can 
extract all the triples methods either the service or the active machine.
Do not try to search keywords in service descriptions, but compare the description with the intent to decide
which one is relevant.
The SPARQL queries you generate must always return full tripes in the form of subject predict object.
Do not forget the predict!
'''

rdf_tool_driver = get_chat_agent(
    "rdf_tool_driver",
    system_message = rdf_tool_driver_system_message
)

rdf_tool_executor = get_fixed_reply_agent(
    "rdf_tool_executor",
    reply = ""
)

register_function(
    query_kg,
    caller = rdf_tool_driver,
    executor = rdf_tool_executor,
    description = "This is the function to query the knowledge graph. The input is a rdf query, "
        "and the output is a list of triples as the query result."
        
)

rdf_tool_executor.register_nested_chats(
    [
        {
            "recipient": rdf_tool_driver,
            "max_turns": 5,
            "summary_method": second_last_msg
        }
    ],
    trigger = lambda sender: sender not in [rdf_tool_driver]
)

# %% [markdown]
# ## Here we go!
# A simple sequence: user_intent -> api_doc_provider -> nerv_tool_executor
#
# Current intent is hard coded.

# %%
user_intent = '''I am Customer1 and own Active_machine6. 
I want to add a new service to my machine to record all the alarms
'''

intent_provider = get_fixed_reply_agent(
    'intent_provier',
    reply = user_intent
)

moderator = get_fixed_reply_agent(
    name="moderator",
    reply = ""
)

decision_chat_results = moderator.initiate_chats(
    [
        {
            "recipient": intent_provider,
            "message": "what do you want?",
            "max_turns": 1,
            "summary_method": "last_msg"
        },
        {
            "recipient": rdf_tool_executor,
            "message": f"Sample triples in the kg: {get_sample_kg()}. Namespaces: {get_namespaces()}",
            "max_turns": 1,
            "summary_method": "last_msg"
        }
    ]
)
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# moderator (to intent_provier):
#
# what do you want?
#
# --------------------------------------------------------------------------------
# intent_provier (to moderator):
#
# I am Customer1 and own Active_machine6.
# I want to add a new service to my machine to record all the alarms
#
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# moderator (to rdf_tool_executor):
#
# Sample triples in the kg: fill:Active_Machine3 intend:has_IP "192.168.10.001"
# fill:Component13 rdf:type intend:Component
# fill:Component10 intend:hasContainer fill:Container38
# fill:Active_Machine8 schema:id "ID161124_Active_Machine8"
# fill:Container18 intend:canBeDeployedOn fill:Machine5
# fill:Active_Machine5 intend:is_machine_type fill:Machine1
# fill:Container23 intend:isContainerOf fill:Component4
# fill:Active_Machine5 schema:name "Active_Machine5"
# fill:Machine1 intend:hasService fill:Service1
# fill:Service2 intend:description "MACHINE STATE provides an overview of your production. The machine status can be called up at any time, allowing workflows to be optimized."
# fill:Service1 intend:hasComponent fill:Container30
# . Namespaces:
# @prefix fill: <https://intendproject.eu/fill/>.
# @prefix intend: <https://intendproject.eu/schema/>.
# @prefix schema: <https://schema.org/>.
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
#
# Context:
# I am Customer1 and own Active_machine6.
# I want to add a new service to my machine to record all the alarms
#
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# rdf_tool_executor (to rdf_tool_driver):
#
# Sample triples in the kg: fill:Active_Machine3 intend:has_IP "192.168.10.001"
# fill:Component13 rdf:type intend:Component
# fill:Component10 intend:hasContainer fill:Container38
# fill:Active_Machine8 schema:id "ID161124_Active_Machine8"
# fill:Container18 intend:canBeDeployedOn fill:Machine5
# fill:Active_Machine5 intend:is_machine_type fill:Machine1
# fill:Container23 intend:isContainerOf fill:Component4
# fill:Active_Machine5 schema:name "Active_Machine5"
# fill:Machine1 intend:hasService fill:Service1
# fill:Service2 intend:description "MACHINE STATE provides an overview of your production. The machine status can be called up at any time, allowing workflows to be optimized."
# fill:Service1 intend:hasComponent fill:Container30
# . Namespaces:
# @prefix fill: <https://intendproject.eu/fill/>.
# @prefix intend: <https://intendproject.eu/schema/>.
# @prefix schema: <https://schema.org/>.
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
#
# Context:
# I am Customer1 and own Active_machine6.
# I want to add a new service to my machine to record all the alarms
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# rdf_tool_driver (to rdf_tool_executor):
#
# ***** Suggested tool call (call_GoDROjng9LWnvzIy3Zkvo7Rv): query_kg *****
# Arguments:
# {"query":"PREFIX intend: <https://intendproject.eu/schema/>\nSELECT ?service ?description WHERE {\n  ?service rdf:type intend:Service .\n  ?service intend:description ?description .\n}"}
# *************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION query_kg...
# rdf_tool_executor (to rdf_tool_driver):
#
# rdf_tool_executor (to rdf_tool_driver):
#
# ***** Response from calling tool (call_GoDROjng9LWnvzIy3Zkvo7Rv) *****
# Error: not enough values to unpack (expected 3, got 2)
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# rdf_tool_driver (to rdf_tool_executor):
#
# ***** Suggested tool call (call_29HFVeq1YbgSvH6Oa8tDYJAb): query_kg *****
# Arguments:
# {"query":"PREFIX intend: <https://intendproject.eu/schema/>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\n\nSELECT ?service ?description WHERE {\n  ?service rdf:type intend:Service .\n  ?service intend:description ?description .\n}"}
# *************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION query_kg...
# rdf_tool_executor (to rdf_tool_driver):
#
# rdf_tool_executor (to rdf_tool_driver):
#
# ***** Response from calling tool (call_29HFVeq1YbgSvH6Oa8tDYJAb) *****
# Error: not enough values to unpack (expected 3, got 2)
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# rdf_tool_driver (to rdf_tool_executor):
#
# ***** Suggested tool call (call_63HOafRDOBEh23gYziOsFUgQ): query_kg *****
# Arguments:
# {"query":"PREFIX intend: <https://intendproject.eu/schema/>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nCONSTRUCT {?service rdf:type intend:Service; intend:description ?description} WHERE {\n  ?service rdf:type intend:Service .\n  ?service intend:description ?description .\n}"}
# *************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION query_kg...
# rdf_tool_executor (to rdf_tool_driver):
#
# rdf_tool_executor (to rdf_tool_driver):
#
# ***** Response from calling tool (call_63HOafRDOBEh23gYziOsFUgQ) *****
# fill:Service7 intend:description "PROGRAM HISTORY automatically records every NC program change. The possibility of analysis and tracking provides more transparency and control."
# fill:Service2 rdf:type intend:Service
# fill:Service7 rdf:type intend:Service
# fill:Service9 rdf:type intend:Service
# fill:Service6 intend:description "DATA XPLORER allows manual analysis of all recorded data. Any questions can thus be clarified independently."
# fill:Service4 intend:description "KPI ANALYZER provides information on the utilization of a machine in a defined period. The analysis provides insights into utilization and efficiency and identifies any bottlenecks or optimization potential."
# fill:Service10 rdf:type intend:Service
# fill:Service2 intend:description "MACHINE STATE provides an overview of your production. The machine status can be called up at any time, allowing workflows to be optimized."
# fill:Service3 rdf:type intend:Service
# fill:Service6 rdf:type intend:Service
# fill:Service3 intend:description "ENERGY TRACKER monitors media consumption and ensures early detection of production changes and leaks that might otherwise go undetected."
# fill:Service11 rdf:type intend:Service
# fill:Service1 intend:description "PROD DATA records all components and the process steps are analyzed. Occurred messages and the tool usage of each component are displayed and provide transparency in the production data."
# fill:Service5 rdf:type intend:Service
# fill:Service10 intend:description "TOOL PERFORMANCE analyzes tool wear. You can determine the condition when replacing tools or compare wear among tools of the same type."
# fill:Service8 rdf:type intend:Service
# fill:Service4 rdf:type intend:Service
# fill:Service12 rdf:type intend:Service
# fill:Service5 intend:description "ALARM ANALYZER records all alarms and messages and identifies the main messages. Actual machine problems can thus be identified."
# fill:Service9 intend:description "THERMO STABILITY detects the constant temperature range for efficient production. This saves time and reduces scrap due to a shorter warm-up phase."
# fill:Service11 intend:description "LOGBOOK logs component changes of motors, spindles and ball screws. In addition, every machine crash is recorded, including the program run."
# fill:Service8 intend:description "G-CODE ANALYZER analyzes the G-code of all components. Optimization potential is suggested to effectively reduce cycle time."
# fill:Service12 intend:description "Test runs generate the specific machine performance indicator. This allows you to detect changes over time and check successful installation after component replacement."
# fill:Service1 rdf:type intend:Service
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# rdf_tool_driver (to rdf_tool_executor):
#
# The service relevant to the user's intent of adding a new service to record all alarms is `Service5`, described as:
#
# - **ALARM ANALYZER**: "ALARM ANALYZER records all alarms and messages and identifies the main messages. Actual machine problems can thus be identified."
#
# The user owns `Active_Machine6`.
#
# Next, I will extract relevant triples that might be associated with both `Service5` and `Active_Machine6`.
# ***** Suggested tool call (call_jfGmQwL1SyqHAuAV6GUfIjcd): query_kg *****
# Arguments:
# {"query":"PREFIX fill: <https://intendproject.eu/fill/>\nPREFIX intend: <https://intendproject.eu/schema/>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX schema: <http://schema.org/>\n\nCONSTRUCT {?s ?p ?o} WHERE {\n  ?s ?p ?o .\n  {\n    ?s ?p fill:Service5 .\n  } UNION {\n    ?s ?p fill:Active_Machine6 .\n  }\n}"}
# *************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION query_kg...
# rdf_tool_executor (to rdf_tool_driver):
#
# rdf_tool_executor (to rdf_tool_driver):
#
# ***** Response from calling tool (call_jfGmQwL1SyqHAuAV6GUfIjcd) *****
# fill:Machine5 intend:hasService fill:Service7
# fill:Machine5 intend:hasService fill:Service3
# fill:Machine2 intend:hasService fill:Service8
# fill:Machine5 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service12
# fill:Machine1 intend:hasService fill:Service8
# fill:Machine2 intend:hasService fill:Service6
# fill:Machine2 intend:hasService fill:Service11
# fill:Machine1 intend:hasService fill:Service12
# fill:Machine1 intend:hasService fill:Service6
# fill:Machine1 intend:hasService fill:Service11
# fill:Machine2 intend:hasService fill:Service10
# fill:Machine5 intend:hasService fill:Service5
# fill:Machine5 intend:hasService fill:Service4
# fill:Machine1 intend:hasService fill:Service10
# fill:Machine5 intend:hasService fill:Service8
# fill:Machine4 intend:hasService fill:Service1
# fill:Machine5 intend:hasService fill:Service11
# fill:Machine5 intend:hasService fill:Service6
# fill:Machine4 intend:hasService fill:Service3
# fill:Machine5 intend:hasService fill:Service10
# fill:Machine4 intend:hasService fill:Service7
# fill:Machine4 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service1
# fill:Machine1 intend:hasService fill:Service1
# fill:Machine4 intend:hasService fill:Service5
# fill:Machine4 intend:hasService fill:Service4
# fill:Machine2 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service3
# fill:Machine2 intend:hasService fill:Service7
# fill:Machine1 intend:hasService fill:Service7
# fill:Machine1 intend:hasService fill:Service3
# fill:Machine2 intend:hasService fill:Service9
# fill:Machine1 intend:hasService fill:Service9
# fill:Machine1 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service5
# fill:Machine5 intend:hasService fill:Service1
# fill:Machine4 intend:hasService fill:Service6
# fill:Machine2 intend:hasService fill:Service4
# fill:Machine1 intend:hasService fill:Service5
# fill:Machine1 intend:hasService fill:Service4
# fill:Machine4 intend:hasService fill:Service10
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# rdf_tool_driver (to rdf_tool_executor):
#
# The `ALARM ANALYZER` service (Service5) is associated with multiple machines. Here are the relevant triples showing these associations:
#
# - Machine2 has Service5
# - Machine4 has Service5
# - Machine5 has Service5
# - Machine1 has Service5
#
# To find out more about `Active_Machine6`, which the user owns, I need to extract additional related triples to help determine how the user can add this service. I'll gather more information about `Active_Machine6`.
# ***** Suggested tool call (call_bAJMYvN7ib4MDyylRNfuhQiG): query_kg *****
# Arguments:
# {"query":"PREFIX fill: <https://intendproject.eu/fill/>\nPREFIX intend: <https://intendproject.eu/schema/>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX schema: <http://schema.org/>\n\nCONSTRUCT {?s ?p ?o} WHERE {\n  fill:Active_Machine6 ?p ?o .\n  ?s ?p fill:Active_Machine6 .\n}"}
# *************************************************************************
#
# --------------------------------------------------------------------------------
# rdf_tool_executor (to moderator):
#
# fill:Machine5 intend:hasService fill:Service7
# fill:Machine5 intend:hasService fill:Service3
# fill:Machine2 intend:hasService fill:Service8
# fill:Machine5 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service12
# fill:Machine1 intend:hasService fill:Service8
# fill:Machine2 intend:hasService fill:Service6
# fill:Machine2 intend:hasService fill:Service11
# fill:Machine1 intend:hasService fill:Service12
# fill:Machine1 intend:hasService fill:Service6
# fill:Machine1 intend:hasService fill:Service11
# fill:Machine2 intend:hasService fill:Service10
# fill:Machine5 intend:hasService fill:Service5
# fill:Machine5 intend:hasService fill:Service4
# fill:Machine1 intend:hasService fill:Service10
# fill:Machine5 intend:hasService fill:Service8
# fill:Machine4 intend:hasService fill:Service1
# fill:Machine5 intend:hasService fill:Service11
# fill:Machine5 intend:hasService fill:Service6
# fill:Machine4 intend:hasService fill:Service3
# fill:Machine5 intend:hasService fill:Service10
# fill:Machine4 intend:hasService fill:Service7
# fill:Machine4 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service1
# fill:Machine1 intend:hasService fill:Service1
# fill:Machine4 intend:hasService fill:Service5
# fill:Machine4 intend:hasService fill:Service4
# fill:Machine2 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service3
# fill:Machine2 intend:hasService fill:Service7
# fill:Machine1 intend:hasService fill:Service7
# fill:Machine1 intend:hasService fill:Service3
# fill:Machine2 intend:hasService fill:Service9
# fill:Machine1 intend:hasService fill:Service9
# fill:Machine1 intend:hasService fill:Service2
# fill:Machine2 intend:hasService fill:Service5
# fill:Machine5 intend:hasService fill:Service1
# fill:Machine4 intend:hasService fill:Service6
# fill:Machine2 intend:hasService fill:Service4
# fill:Machine1 intend:hasService fill:Service5
# fill:Machine1 intend:hasService fill:Service4
# fill:Machine4 intend:hasService fill:Service10
#
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Next steps:
#
# 1. Replace current api_doc_provider (a fixed_reply_agent) by a RAG assistant, that extracts from a complete API document the parts that are relevant to DNA and deployment.
# 2. Add in the beginning of the sequence another agent (or agents) to extract the list of workloads. Eventually, the input intent should be like "I want to be able to monitor the thermal stability of machine M0001"
